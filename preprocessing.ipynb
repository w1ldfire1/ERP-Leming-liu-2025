# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
london_data = pd.read_csv('London_Housing_Policy_Dataset.csv', parse_dates=['Date'])
london_data = london_data.sort_values('Date')

scaler = StandardScaler()
X_scaled = scaler.fit_transform(london_data.drop(columns=['Date']))
X = pd.DataFrame(X_scaled, columns=london_data.columns[1:], index=london_data['Date'])
london_data_sd=X.reset_index()
london_data_sd.to_csv("London_Housing_Policy_Dataset_sd.csv", index=False)

# %%
london_data_sd
# Out:
#           Date  Average_Housing_Price  Weekly_Earnings  Employment_Rate  \
# 0   2009-01-01              -1.790378        -1.151831        -1.015628
# 1   2009-02-01              -1.825122        -1.151831        -0.903238
# 2   2009-03-01              -1.852767        -1.151831        -1.154297
# 3   2009-04-01              -1.873244        -1.182109        -1.293380
# 4   2009-05-01              -1.823572        -1.182109        -1.424641
# ..         ...                    ...              ...              ...
# 187 2024-08-01               1.183071         2.052053         1.265820
# 188 2024-09-01               1.191820         2.052053         1.322332
# 189 2024-10-01               1.085279         2.052053         1.423254
# 190 2024-11-01               1.012152         2.052053         1.333089
# 191 2024-12-01               1.012442         2.052053         1.333089
#
#      Benefit Caseload  Housing Supply  Euro Rate  Interest Rate  Seasonal_Diff
# ...

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
NW_data = pd.read_csv('North_West_Housing_Policy_Dataset.csv', parse_dates=['Date'])
NW_data = NW_data.sort_values('Date')

scaler = StandardScaler()
X_scaled = scaler.fit_transform(NW_data.drop(columns=['Date']))
X = pd.DataFrame(X_scaled, columns=NW_data.columns[1:], index=NW_data['Date'])
NW_data_sd=X.reset_index()
NW_data_sd.to_csv("North_West_Housing_Policy_Dataset_sd.csv", index=False)

# %%
NW_data_sd
# Out:
#           Date  Average_Housing_Price  Weekly_Earnings  Employment_Rate  \
# 0   2009-01-01              -1.025891        -1.104066         0.031666
# 1   2009-02-01              -1.042841        -1.104066        -0.004609
# 2   2009-03-01              -1.115311        -1.104066        -0.655363
# 3   2009-04-01              -1.016581        -1.215335        -0.675076
# 4   2009-05-01              -1.002018        -1.215335        -0.828855
# ..         ...                    ...              ...              ...
# 188 2024-08-01               2.049761         2.364837         1.164405
# 189 2024-09-01               2.066404         2.364837         0.962781
# 190 2024-10-01               2.078784         2.364837         0.748241
# 191 2024-11-01               2.145866         2.364837         0.399317
# 192 2024-12-01               2.107533         2.364837         0.399317
#
#      Benefit Caseload  Housing Supply  Euro Rate  Interest Rate
# ...
